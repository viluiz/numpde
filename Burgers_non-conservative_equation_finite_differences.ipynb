# %%
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
# Gauss-Seidel iterative solution of Ax=b
def gauss_seidel(A, b, x, tolerance=1e-10, max_iterations=1000):
    iter1 = 0
    for k in range(max_iterations):
        iter1 += 1   
        x_old  = x.copy()
        #Loop over rows
        for i in range(A.shape[0]):
            x[i] = (b[i] - np.dot(A[i,:i], x[:i]) - np.dot(A[i,(i+1):], x_old[(i+1):])) / A[i ,i]
        #Stop condition 
        if  max(abs((x - x_old)))/max(abs(x_old)) < tolerance:
            break
    #print("The L infinity norm in iteration", iter1,"is:", max(abs((x - x_old)))/max(abs(x_old)))       
    return x

# solve the linear system Ax=b
def solve_linear(A, b):
        #return np.linalg.solve(A, b)
        return gauss_seidel(A, b, -b)
        #return np.linalg.pinv(A).dot(b)

# %% [markdown]
# ### Burgers equation  (\*\*\*the non-conservative form cannot represent the evolution of the shock properly\*\*\*)
#
# $
# \frac{\displaystyle \partial u}{\displaystyle \partial t} + u  \frac{\displaystyle \partial u}{\displaystyle \partial x} = \alpha \frac{\displaystyle \partial^2 u}{\displaystyle \partial x^2} + f
# $
#
# #### Courant–Friedrichs–Lewy number
#
# $
# CFL = \frac{\displaystyle u \Delta t}{\displaystyle \Delta x}  \hspace{0.5cm} \text{one dimentional}\\
# CFL \le 1
# $
#
# #### Von Neumann stability condition (for explicit)
#
# $
# r = \frac{\displaystyle \alpha \Delta t}{\displaystyle (\Delta x)^2} \\
# r \le \frac{\displaystyle 1}{\displaystyle 2}
# $

# %%
# (solve Au=f for each time step) 

class Burgers: 
    """
    Finite difference solution of the Burgers equation (nonlinear hyperbolic equation, for alpha=0)
    ***the non-conservative form cannot represent the evolution of the shock properly***
    
    Parameters
    ----------
    alpha: float
        Diffusivity in m*m/s    
    dx: float
        Block size in meters
    N: int
        Number of blocks
    initial_condition: list (or numpy array) of floats
        Initial condition (one value per block -> size N)
    boundary_type: list (or numpy array) of str | default ['Dirichlet','Dirichlet']
        Left and right boundary condition type (options: 'Dirichlet', 'Neumann' or 'periodic'), e.g. ['Dirichlet','Neumann'] or ['periodic','periodic']  
    boundary_values: list (or numpy array) of floats | default [0., 0.]    
        Left and right boundary condition values, e.g. [10., -1.]
    time_integration: str | default 'implicit'
        Time integration (options: explict, implicit or Crank-Nicolson), e.g. 'implicit'
    space_discretization: str | default 'upwind'
        Space discretization (options: central or upwind), e.g. 'upwind'
    
    Methods
    -------
    forward(dt, source_term=None)
        Solve the transport equation for one time step of size dt considering the source term

    """  
    def __init__(self, alpha, dx, N, initial_condition, boundary_type = ['Dirichlet','Dirichlet'], boundary_values=[0, 0], time_integration='implicit', space_discretization='upwind'):   
        self.alpha = alpha
        self.dx = dx 
        self.N = N  
        self.u_previous = np.array(initial_condition) # For the first time step
        self.boundary_type = boundary_type
        self.boundary_values = boundary_values
        self.time_integration = time_integration 
        self.space_discretization = space_discretization
        self.timestep_count = 0
        if time_integration == 'implicit' or time_integration == 'Crank-Nicolson':
            self.A = np.empty((N,N))
            self.f = np.empty(N)
    
    # Solve the PDE discretized equation explicitly  
    def solve_explicit(self, dt, source_term):
        
        #Define w (upwind or central) advection space discretization
        if self.space_discretization == 'upwind':
            self.w = (self.u_previous>0)
        elif self.space_discretization == 'central':
            self.w = np.ones(len(self.u_previous))*0.5
        else:
            print(f'Space discretization {self.space_discretization} NOT available!')  
        
        # Define Courant–Friedrichs–Lewy number
        cfl = self.u_previous*dt/self.dx
    
        # Define r
        r = self.alpha*dt/(self.dx*self.dx)
        
        # initialize u and add source term
        u = self.u_previous + dt*source_term
        
        #----------
        # Calculate advection and diffusion terms for elements not in the boundary
        #
        ## Advective term
        for i in range(1,self.N-1): 
            u[i] += -cfl[i]*((self.u_previous[i+1]-self.u_previous[i])*(1-self.w[i])+(self.u_previous[i]-self.u_previous[i-1])*self.w[i])  
        ## Diffusive term
        for i in range(1,self.N-1):  
            u[i] += r*(self.u_previous[i-1]-2*self.u_previous[i]+self.u_previous[i+1])              
        
        #----------      
        # Calculate advection and diffusion terms for elements in the boundaries 
        #
        ## Left boundary
        if self.boundary_type[0] == 'Dirichlet':
            #
            ### Advective term 
            u[0] += -cfl[0]*((self.u_previous[1]-self.u_previous[0])*(1-self.w[0])+(self.u_previous[0]-self.boundary_values[0])*self.w[0]) 
            ### Diffusive term
            u[0] += r*(self.boundary_values[0]-2*self.u_previous[0]+self.u_previous[1])             
        elif self.boundary_type[0] == 'Neumann':
            #
            ### Advective term 
            u[0] += -cfl[0]*((self.u_previous[1]-self.u_previous[0])*(1-self.w[0])+(self.dx*self.boundary_values[0])*self.w[0])   
            ### Diffusive term
            u[0] += r*(-self.dx*self.boundary_values[0]-self.u_previous[0]+self.u_previous[1]) 
        elif self.boundary_type[0] == 'periodic':
            #
            ### Advective term 
            u[0] += -cfl[0]*((self.u_previous[1]-self.u_previous[0])*(1-self.w[0])+(self.u_previous[0]-self.u_previous[-1])*self.w[0])    
            ### Diffusive term
            u[0] += r*(self.u_previous[-1]-2*self.u_previous[0]+self.u_previous[1]) 
        else:
            print('Left boundary: no condition satisfaed!')    
        #
        ## Right boundary
        if self.boundary_type[1] == 'Dirichlet':
            #
            ### Advective term 
            u[-1] += -cfl[-1]*((self.boundary_values[-1]-self.u_previous[-1])*(1-self.w[-1])+(self.u_previous[-1]-self.u_previous[-2])*self.w[-1])       
            ### Diffusive term
            u[-1] += r*(self.u_previous[-2]-2*self.u_previous[-1]+self.boundary_values[-1]) 
        elif self.boundary_type[1] == 'Neumann':
            #
            ### Advective term             
            u[-1] += -cfl[-1]*((self.dx*self.boundary_values[-1])*(1-self.w[-1])+(self.u_previous[-1]-self.u_previous[-2])*self.w[-1])  
            ### Diffusive term
            u[-1] += r*(self.u_previous[-2]-self.u_previous[-1]+self.dx*self.boundary_values[-1])                 
        elif self.boundary_type[1] == 'periodic':
            #
            ### Advective term             
            u[-1] += -cfl[-1]*((self.u_previous[0]-self.u_previous[-1])*(1-self.w[-1])+(self.u_previous[-1]-self.u_previous[-2])*self.w[-1])    
            ### Diffusive term
            u[-1] += r*(self.u_previous[-2]-2*self.u_previous[-1]+self.u_previous[0])                 
        else:
            print('Left boundary: no condition satisfaed!')          
                       
        return u

    # Solve the PDE discretized equation fully implicit  
    def solve_implicit(self, dt, source_term):
        
        # u values to start the nonlinear iteration
        u_previous_nl = self.u_previous
        
        # Nonlinear loop (Picard)
        for j in range(20):
            
            #Define w (upwind or central) advection space discretization
            if self.space_discretization == 'upwind':
                self.w = (u_previous_nl>0)
            elif self.space_discretization == 'central':
                self.w = np.ones(len(u_previous_nl))*0.5
            else:
                print(f'Space discretization {self.space_discretization} NOT available!') 

            # Define multiplicative constant. 
            c = dt/self.dx

            # Define r
            r = self.alpha*dt/(self.dx*self.dx)

            #----------
            # (Au=f) Calculate matrix A and f 
            #
            ## matrix A
            self.A[:] = np.diag([1]*self.N, 0)  # Main diagonal (identity)
            #
            ### Advective term 
            self.A += np.diag(-c*u_previous_nl*(1-self.w)+c*u_previous_nl*self.w,  0)     # Main diagonal
            self.A += np.diag(c*u_previous_nl[:-1]*(1-self.w[:-1]), 1)                     # Upper diagonal
            self.A += np.diag(-c*u_previous_nl[1:]*self.w[1:],-1)                        # Lower diagonal       
            #
            ### Diffusive term
            self.A += np.diag([2*r]*self.N,  0)      # Main diagonal
            self.A += np.diag([-r]*(self.N-1), 1)    # Upper diagonal
            self.A += np.diag([-r]*(self.N-1),-1)    # Lower diagonal  
            #
            ## Source term plus constants f
            self.f[:] = self.u_previous + dt*source_term    


            # ----------
            # Calculate boundary conditions 
            #
            ## Left boundary
            if self.boundary_type[0] == 'Dirichlet':
                #
                ### Advective term             
                self.f[0] += self.boundary_values[0]*c*u_previous_nl[0]*self.w[0]  
                ### Diffusive term      
                self.f[0] += self.boundary_values[0]*r 
            elif self.boundary_type[0] == 'Neumann':
                #
                ### Advective term               
                self.f[0]  += -self.boundary_values[0]*c*u_previous_nl[0]*self.dx*self.w[0]   
                self.A[0,0] += -c*u_previous_nl[0]*self.w[0]
                ### Diffusive term      
                self.f[0]  += -self.boundary_values[0]*r*self.dx   
                self.A[0,0] += -r                
            elif self.boundary_type[0] == 'periodic':
                #
                ### Advective term               
                self.A[0,-1] += -c*u_previous_nl[0]*self.w[0]  
                ### Diffusive term     
                self.A[0,-1] += -r                
            else:
                print('Left boundary: no condition satisfaed!')
            #
            ## Right boundary
            if self.boundary_type[1] == 'Dirichlet':
                #
                ### Advective term              
                self.f[-1] += -self.boundary_values[-1]*c*u_previous_nl[-1]*(1-self.w[-1])
                ### Diffusive term     
                self.f[-1] += self.boundary_values[-1]*r
            elif self.boundary_type[1] == 'Neumann':
                #
                ### Advective term              
                self.f[-1] += -self.boundary_values[-1]*c*u_previous_nl[-1]*self.dx*(1-self.w[-1])  
                self.A[-1,-1] += c*u_previous_nl[-1]*(1-self.w[-1])
                ### Diffusive term     
                self.f[-1] += self.boundary_values[-1]*r*self.dx  
                self.A[-1,-1] += -r            
            elif self.boundary_type[1] == 'periodic':
                #
                ### Advective term              
                self.A[-1,0] += c*u_previous_nl[-1]*(1-self.w[-1])
                ### Diffusive term     
                self.A[-1,0] += -r
            else:
                print('Right boundary: no condition satisfaed!')         

            # Calculate u from Au=f
            u = solve_linear(self.A, self.f)
            error = max(abs((u-u_previous_nl)/(u_previous_nl+1e-6)))
            print(f'Nonlinear iteration {j} error: {error}')
            if error < 0.001:
                break
            
            # u values from the last nonlinear iteration
            u_previous_nl = u
    
        return u
    
    # Solve the PDE discretized equation using Crank-Nicolson (theta = 0 -> explicit, 1-> implicit)
    def solve_CrankNicolson(self, dt, source_term, theta=0.5):
        
        # u values to start the nonlinear iteration
        u_previous_nl = self.u_previous
        
        # Nonlinear loop (Picard)
        for j in range(10):
        
            #Define w (upwind or central) advection space discretization
            if self.space_discretization == 'upwind':
                self.w = (u_previous_nl>0)
            elif self.space_discretization == 'central':
                self.w = np.ones(len(u_previous_nl))*0.5
            else:
                print(f'Space discretization {self.space_discretization} NOT available!') 

            # Define multiplicative constant. 
            c = dt/self.dx  

            # Define r
            r = self.alpha*dt/(self.dx*self.dx)        

            #----------
            # (Au=f) Calculate matrix A and f 
            #
            ## matrix A
            self.A[:] = np.diag([1]*self.N, 0)  # Main diagonal (identity)
            #
            ### Advective term         
            self.A += np.diag(-theta*c*u_previous_nl*(1-self.w)+theta*c*u_previous_nl*self.w,  0)    # Main diagonal
            self.A += np.diag(theta*c*u_previous_nl[:-1]*(1-self.w[:-1]), 1)                         # Upper diagonal
            self.A += np.diag(-theta*c*u_previous_nl[1:]*self.w[1:],-1)                              # Lower diagonal   
            #
            ### Diffusive term       
            self.A += np.diag([2*r*theta]*self.N,  0)      # Main diagonal
            self.A += np.diag([-r*theta]*(self.N-1), 1)    # Upper diagonal
            self.A += np.diag([-r*theta]*(self.N-1),-1)    # Lower diagonal          
            #
            #
            ## Source term plus constants f
            self.f[:] = self.u_previous + dt*source_term
            ### Advective term    
            for i in range(1,self.N-1):
                self.f[i] += -(1-theta)*c*u_previous_nl[i]*((self.u_previous[i+1]-self.u_previous[i])*(1-self.w[i])+(self.u_previous[i]-self.u_previous[i-1])*self.w[i]) 
            ### Diffusive term       
            for i in range(1,self.N-1):
                self.f[i] += r*(1-theta)*(self.u_previous[i-1]-2*self.u_previous[i]+self.u_previous[i+1])        

            #----------
            # Calculate boundary conditions 
            #
            ## Left boundary
            if self.boundary_type[0] == 'Dirichlet':
                #
                ### Advective term               
                self.f[0] += -(1-theta)*c*u_previous_nl[0]*((self.u_previous[1]-self.u_previous[0])*(1-self.w[0])+(self.u_previous[0]-self.boundary_values[0])*self.w[0])
                self.f[0] += theta*self.boundary_values[0]*c*u_previous_nl[0]*self.w[0] 
                ### Diffusive term         
                self.f[0] += (1-theta)*r*(self.boundary_values[0]-2*self.u_previous[0]+self.u_previous[1])
                self.f[0] += theta*r*self.boundary_values[0]            
            elif self.boundary_type[0] == 'Neumann':
                #
                ### Advective term               
                self.f[0] += -(1-theta)*c*u_previous_nl[0]*((self.u_previous[1]-self.u_previous[0])*(1-self.w[0])+(self.dx*self.boundary_values[0])*self.w[0])
                self.f[0] += -theta*self.boundary_values[0]*c*u_previous_nl[0]*self.dx*self.w[0] 
                self.A[0,0] += -theta*c*u_previous_nl[0]*self.w[0]
                ### Diffusive term        
                self.f[0] += (1-theta)*r*(-self.dx*self.boundary_values[0]-self.u_previous[0]+self.u_previous[1])
                self.f[0] += -theta*self.dx*r*self.boundary_values[0]     
                self.A[0,0] += -r*theta
            elif self.boundary_type[0] == 'periodic':
                #
                ### Advective term               
                self.f[0] += -(1-theta)*c*u_previous_nl[0]*((self.u_previous[1]-self.u_previous[0])*(1-self.w[0])+(self.u_previous[0]-self.u_previous[-1])*self.w[0])                
                self.A[0,-1] += -theta*c*u_previous_nl[0]*self.w[0]  
                ### Diffusive term   
                f[0] += (1-theta)*r*(self.u_previous[-1]-2*self.u_previous[0]+self.u_previous[1]) 
                self.A[0,-1] += -theta*r 
            else:
                print('Left boundary: no condition satisfaed!')
            #
            ## Right boundary
            if self.boundary_type[1] == 'Dirichlet':
                #
                ### Advective term              
                self.f[-1] += -(1-theta)*c*u_previous_nl[-1]*((self.boundary_values[-1]-self.u_previous[-1])*(1-self.w[-1])+(self.u_previous[-1]-self.u_previous[-2])*self.w[-1])
                self.f[-1] += -theta*self.boundary_values[-1]*c*u_previous_nl[-1]*(1-self.w[-1])    
                ### Diffusive term   
                self.f[-1] += (1-theta)*r*(self.u_previous[-2]-2*self.u_previous[-1]+self.boundary_values[-1])
                self.f[-1] += theta*r*self.boundary_values[-1]            
            elif self.boundary_type[1] == 'Neumann':
                #
                ### Advective term              
                self.f[-1] += -(1-theta)*c*u_previous_nl[-1]*((self.dx*self.boundary_values[-1])*(1-self.w[-1])+(self.u_previous[-1]-self.u_previous[-2])*self.w[-1])
                self.f[-1] += -theta*self.boundary_values[-1]*c*u_previous_nl[-1]*self.dx*(1-self.w[-1]) 
                self.A[-1,-1] += theta*c*u_previous_nl[-1]*(1-self.w[-1]) 
                ### Diffusive term   
                self.f[-1] += (1-theta)*r*(self.u_previous[-2]-self.u_previous[-1]+self.dx*self.boundary_values[-1])
                self.f[-1] += self.dx*r*theta*self.boundary_values[-1] 
                self.A[-1,-1] += -r*theta            
            elif self.boundary_type[1] == 'periodic':
                #
                ### Advective term              
                self.f[-1] += -(1-theta)*c*u_previous_nl[-1]*((self.u_previous[0]-self.u_previous[-1])*(1-self.w[-1])+(self.u_previous[-1]-self.u_previous[-2])*self.w[-1])                
                self.A[-1,0] += theta*c*u_previous_nl[-1]*(1-self.w[-1])   
                ### Diffusive term   
                self.f[-1] += (1-theta)*r*(self.u_previous[-2]-2*self.u_previous[-1]+self.u_previous[0])
                self.A[-1,0] += -theta*r            
            else:
                print('Right boundary: no condition satisfaed!')

            # Calculate u from Au=f
            u = solve_linear(self.A, self.f)
            error = max(abs((u-u_previous_nl)/(u_previous_nl+1e-6)))
            print(f'Nonlinear iteration {j} error: {error}')
            if error < 0.001:
                break
            
            # u values from the last nonlinear iteration
            u_previous_nl = u
        
        return u 
    
            
    def forward(self, dt, source_term=None):
        """
        Solve the advection/convection-diffusion equation for one time step of size dt considering the source term
        
        
        Parameters
        ----------
        dt: float
            Time step size in seconds
        source_term: list (or numpy array) of floats | default None
            Source term (one value per block -> size N)
        
        Returns
        ----------
        u: numpy array of floats
            resulted field after time step dt (one value per block -> size N)

        """          
        source_term = np.array(self.N*[0]) if source_term == None else np.array(source_term)
        
        if self.time_integration == 'implicit':
            self.timestep_count += 1
            print(f'Time step {self.timestep_count} => dt = {dt}s, cfl = {max(self.u_previous)*dt/self.dx:.2f}, r = {self.alpha*dt/(self.dx*self.dx):.2f}, total time = {self.timestep_count*dt}s')
           
            u = self.solve_implicit(dt, source_term)
            self.u_previous[:] = u
            
        elif self.time_integration == 'Crank-Nicolson':
            self.timestep_count += 1
            print(f'Time step {self.timestep_count} => dt = {dt}s, cfl = {max(self.u_previous)*dt/self.dx:.2f}, r = {self.alpha*dt/(self.dx*self.dx):.2f}, total time = {self.timestep_count*dt}s')
          
            u = self.solve_CrankNicolson(dt, source_term, theta=0.5)
            self.u_previous[:] = u            
        
        elif self.time_integration == 'explicit':
            self.timestep_count += 1
            print(f'Time step {self.timestep_count} => dt = {dt}s, cfl = {max(self.u_previous)*dt/self.dx:.2f}{"(***WARNING cfl>1)" if max(self.u_previous)*dt/self.dx > 1.0 else ""}, r = {self.alpha*dt/(self.dx*self.dx):.2f}{"(***WARNING r>=1/2)" if self.alpha*dt/(self.dx*self.dx) >= 0.5 else ""}, total time = {self.timestep_count*dt}s')
           
            u = self.solve_explicit(dt, source_term)
            self.u_previous[:] = u
            
        else:
            print(f'Time integration {self.time_integration} NOT available!')
            return None
        
        return u

# %% [markdown]
# ### Solve implicit

# %%
burgers = Burgers(alpha=0.0,
            dx=1.0,
            N=150, 
            initial_condition = list(np.sin(np.linspace(0,2*np.pi,150,endpoint=False))+0.5), #50*[10.]+50*[0.]+50*[0.], 
            #boundary_type = ['Dirichlet','Neumann'],
            #boundary_type = ['Dirichlet','Dirichlet'], 
            boundary_type = ['Neumann','Neumann'], 
            #boundary_type = ['periodic','periodic'], 
            boundary_values = [0, 0],
            time_integration='implicit',
            space_discretization='upwind')

# %%
# Initialize u
u=[]
u.append(burgers.u_previous.copy())  # Initial condition

# %%
start = time.time()
for _ in range(50):
    u.append(burgers.forward(dt=0.5, # seconds
                               #source_term=1*[0.]+9*[0.]+1*[0.]
                               )
            )
print(time.time()-start)
plt.plot(np.transpose(u));
u_imp = u
# Out:
# Time step 1 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 0.5s
# Nonlinear iteration 0 error: 0.021382660694461826
# Nonlinear iteration 1 error: 0.00045716517446408857
# Time step 2 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 1.0s
# Nonlinear iteration 0 error: 0.021853207584184957
# Nonlinear iteration 1 error: 0.0004773336852391692
# Time step 3 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 1.5s
# Nonlinear iteration 0 error: 0.022340692760895637
# Nonlinear iteration 1 error: 0.0004989956142562397
# Time step 4 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 2.0s
# Nonlinear iteration 0 error: 0.022854135017089737
# Nonlinear iteration 1 error: 0.0005222957481085587
# Time step 5 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 2.5s
# Nonlinear iteration 0 error: 0.02339398798611378
# Nonlinear iteration 1 error: 0.0005470248973689435
# Time step 6 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 3.0s
# Nonlinear iteration 0 error: 0.023954487254117664
# Nonlinear iteration 1 error: 0.0005733678793656297
# Time step 7 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 3.5s
# Nonlinear iteration 0 error: 0.02453942608905878
# Nonlinear iteration 1 error: 0.0006022445359791004
# Time step 8 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 4.0s
# Nonlinear iteration 0 error: 0.025165158708957053
# Nonlinear iteration 1 error: 0.0006330195842216293
# Time step 9 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 4.5s
# Nonlinear iteration 0 error: 0.0258164603957775
# Nonlinear iteration 1 error: 0.0006657861743805664
# Time step 10 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 5.0s
# Nonlinear iteration 0 error: 0.026493502729048626
# Nonlinear iteration 1 error: 0.0007017718699295309
# Time step 11 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 5.5s
# Nonlinear iteration 0 error: 0.027220860663071656
# Nonlinear iteration 1 error: 0.0007407333034899457
# Time step 12 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 6.0s
# Nonlinear iteration 0 error: 0.027987042894187696
# Nonlinear iteration 1 error: 0.0007824068001166946
# Time step 13 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 6.5s
# Nonlinear iteration 0 error: 0.02878561352574351
# Nonlinear iteration 1 error: 0.0008276399131444841
# Time step 14 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 7.0s
# Nonlinear iteration 0 error: 0.029632611251467992
# Nonlinear iteration 1 error: 0.0008779601177802085
# Time step 15 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 7.5s
# Nonlinear iteration 0 error: 0.030547074536426473
# Nonlinear iteration 1 error: 0.000932081127711371
# Time step 16 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 8.0s
# Nonlinear iteration 0 error: 0.031503265609161335
# Nonlinear iteration 1 error: 0.0009901445729855018
# Time step 17 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 8.5s
# Nonlinear iteration 0 error: 0.03250020935005957
# Nonlinear iteration 1 error: 0.001056174938609054
# Nonlinear iteration 2 error: 3.539058219089034e-05
# Time step 18 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 9.0s
# Nonlinear iteration 0 error: 0.033607510526394636
# Nonlinear iteration 1 error: 0.0011282943503851822
# Nonlinear iteration 2 error: 3.906050055037755e-05
# Time step 19 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 9.5s
# Nonlinear iteration 0 error: 0.034774467525221946
# Nonlinear iteration 1 error: 0.001206145558576188
# Nonlinear iteration 2 error: 4.31497973986049e-05
# Time step 20 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 10.0s
# Nonlinear iteration 0 error: 0.03599513102555421
# Nonlinear iteration 1 error: 0.001292948208903371
# Nonlinear iteration 2 error: 4.810534729472111e-05
# Time step 21 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 10.5s
# Nonlinear iteration 0 error: 0.03732250072632436
# Nonlinear iteration 1 error: 0.0013918958684706328
# Nonlinear iteration 2 error: 5.3701759468368273e-05
# Time step 22 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 11.0s
# Nonlinear iteration 0 error: 0.038777412854931276
# Nonlinear iteration 1 error: 0.0014995654551223654
# Nonlinear iteration 2 error: 5.999185270978218e-05
# Time step 23 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 11.5s
# Nonlinear iteration 0 error: 0.04030607404004596
# Nonlinear iteration 1 error: 0.0016160185719775037
# Nonlinear iteration 2 error: 6.745625401844469e-05
# Time step 24 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 12.0s
# Nonlinear iteration 0 error: 0.04190215388357096
# Nonlinear iteration 1 error: 0.0017555991164862842
# Nonlinear iteration 2 error: 7.641176275023519e-05
# Time step 25 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 12.5s
# Nonlinear iteration 0 error: 0.04376666221605504
# Nonlinear iteration 1 error: 0.0019104843522258703
# Nonlinear iteration 2 error: 8.662964548827093e-05
# Time step 26 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 13.0s
# Nonlinear iteration 0 error: 0.0457386385933897
# Nonlinear iteration 1 error: 0.002079619306857909
# Nonlinear iteration 2 error: 9.81828627821338e-05
# Time step 27 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 13.5s
# Nonlinear iteration 0 error: 0.04780722501635341
# Nonlinear iteration 1 error: 0.002272236888216169
# Nonlinear iteration 2 error: 0.0001132150062550569
# Time step 28 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 14.0s
# Nonlinear iteration 0 error: 0.05010826551451813
# Nonlinear iteration 1 error: 0.0025062701947757096
# Nonlinear iteration 2 error: 0.00013093544048753633
# Time step 29 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 14.5s
# Nonlinear iteration 0 error: 0.052751331919162626
# Nonlinear iteration 1 error: 0.0027656988011553435
# Nonlinear iteration 2 error: 0.00015138220023608353
# Time step 30 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 15.0s
# Nonlinear iteration 0 error: 0.055548391027640115
# Nonlinear iteration 1 error: 0.003049440543792457
# Nonlinear iteration 2 error: 0.00017553757632615062
# Time step 31 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 15.5s
# Nonlinear iteration 0 error: 0.058466605598524214
# Nonlinear iteration 1 error: 0.0034009347945569667
# Nonlinear iteration 2 error: 0.0002088500008242062
# Time step 32 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 16.0s
# Nonlinear iteration 0 error: 0.062019541696575614
# Nonlinear iteration 1 error: 0.003827925889742088
# Nonlinear iteration 2 error: 0.0002486049238665989
# Time step 33 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 16.5s
# Nonlinear iteration 0 error: 0.06602383017459847
# Nonlinear iteration 1 error: 0.004306045078610545
# Nonlinear iteration 2 error: 0.0002951887588073396
# Time step 34 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 17.0s
# Nonlinear iteration 0 error: 0.07026210758058439
# Nonlinear iteration 1 error: 0.004829336939309699
# Nonlinear iteration 2 error: 0.00035201351028357866
# Time step 35 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 17.5s
# Nonlinear iteration 0 error: 0.0746413210500053
# Nonlinear iteration 1 error: 0.005533879270375909
# Nonlinear iteration 2 error: 0.00043864267390500146
# Time step 36 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 18.0s
# Nonlinear iteration 0 error: 0.08054279883004388
# Nonlinear iteration 1 error: 0.00643055717817047
# Nonlinear iteration 2 error: 0.000546570727474182
# Time step 37 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 18.5s
# Nonlinear iteration 0 error: 0.08729502911642466
# Nonlinear iteration 1 error: 0.007458378201520604
# Nonlinear iteration 2 error: 0.0006774418358398818
# Time step 38 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 19.0s
# Nonlinear iteration 0 error: 0.0944967633619499
# Nonlinear iteration 1 error: 0.008595728082088137
# Nonlinear iteration 2 error: 0.0008295362527956987
# Time step 39 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 19.5s
# Nonlinear iteration 0 error: 0.10189111256066292
# Nonlinear iteration 1 error: 0.010009056583452539
# Nonlinear iteration 2 error: 0.0010937715362668706
# Nonlinear iteration 3 error: 0.00011925425733255284
# Time step 40 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 20.0s
# Nonlinear iteration 0 error: 0.11167079257794316
# Nonlinear iteration 1 error: 0.012371627368033222
# Nonlinear iteration 2 error: 0.0014933103600060864
# Nonlinear iteration 3 error: 0.00017909446544604252
# Time step 41 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 20.5s
# Nonlinear iteration 0 error: 0.12549945636724594
# Nonlinear iteration 1 error: 0.015305716166732326
# Nonlinear iteration 2 error: 0.0020349318291851314
# Nonlinear iteration 3 error: 0.00026797225164105186
# Time step 42 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 21.0s
# Nonlinear iteration 0 error: 0.14106167145927823
# Nonlinear iteration 1 error: 0.018815043977644497
# Nonlinear iteration 2 error: 0.0027383445773091087
# Nonlinear iteration 3 error: 0.00039419239079408505
# Time step 43 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 21.5s
# Nonlinear iteration 0 error: 0.15781516630229084
# Nonlinear iteration 1 error: 0.02276564607717742
# Nonlinear iteration 2 error: 0.003589234449015546
# Nonlinear iteration 3 error: 0.0005600946231518144
# Time step 44 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 22.0s
# Nonlinear iteration 0 error: 0.1746457753282526
# Nonlinear iteration 1 error: 0.02680446417878237
# Nonlinear iteration 2 error: 0.004506014784016533
# Nonlinear iteration 3 error: 0.0007516146139571259
# Time step 45 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 22.5s
# Nonlinear iteration 0 error: 0.1897719460473989
# Nonlinear iteration 1 error: 0.030313163676087874
# Nonlinear iteration 2 error: 0.005313946156192383
# Nonlinear iteration 3 error: 0.0009274225850158833
# Time step 46 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 23.0s
# Nonlinear iteration 0 error: 0.20085803881205194
# Nonlinear iteration 1 error: 0.03247623497107944
# Nonlinear iteration 2 error: 0.005765358626410486
# Nonlinear iteration 3 error: 0.0010220320550037992
# Nonlinear iteration 4 error: 0.00017975196503853806
# Time step 47 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 23.5s
# Nonlinear iteration 0 error: 0.20543829116717796
# Nonlinear iteration 1 error: 0.03252347819244509
# Nonlinear iteration 2 error: 0.005639549860336882
# Nonlinear iteration 3 error: 0.00097804861043405
# Time step 48 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 24.0s
# Nonlinear iteration 0 error: 0.20179931897304323
# Nonlinear iteration 1 error: 0.030144200636445812
# Nonlinear iteration 2 error: 0.00490162299956573
# Nonlinear iteration 3 error: 0.0007969298520373128
# Time step 49 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 24.5s
# Nonlinear iteration 0 error: 0.18965101692763375
# Nonlinear iteration 1 error: 0.025718107687173156
# Nonlinear iteration 2 error: 0.003758466921103482
# Nonlinear iteration 3 error: 0.0005480774366128382
# Time step 50 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 25.0s
# Nonlinear iteration 0 error: 0.17054941951776253
# Nonlinear iteration 1 error: 0.020234936577920044
# Nonlinear iteration 2 error: 0.0025531793852912143
# Nonlinear iteration 3 error: 0.0003204106597634059
# 1.3945324420928955

# %%
#print('A = \n', burgers.A)
print()
#print('u = \n', u[-1])
print()
#print('f = \n', burgers.f)
print()
print('Determinant =', np.linalg.det(burgers.A))
print('Error = ', np.max(abs(burgers.A.dot(u[-1])-burgers.f)))

plt.plot(burgers.A.dot(u[-1]))
plt.plot(burgers.f, '--')
# Out:
# Determinant = 6.972427183462996e+18
# Error =  1.4094225786465131e-11

# %%
#print(u_imp[-1])
fig, axes = plt.subplots(1,2, figsize=(20,5))
axes[0].plot(np.array(u_imp)[:,5])
axes[1].plot(u_imp[-1])

# %% [markdown]
# ### Solve explicit

# %%
burgers = Burgers(alpha=0.0,
            dx=1.0,
            N=150, 
            initial_condition = list(np.sin(np.linspace(0,2*np.pi,150,endpoint=False))+0.5), #50*[10.]+50*[0.]+50*[0.], 
            #boundary_type = ['Dirichlet','Neumann'], 
            #boundary_type = ['Dirichlet','Dirichlet'], 
            boundary_type = ['Neumann','Neumann'], 
            #boundary_type = ['periodic','periodic'], 
            boundary_values = [0, 0],
            time_integration='explicit',
            space_discretization='upwind')

# %%
# Initialize u
u=[]
u.append(burgers.u_previous.copy())  # Initial condition

# %%
start = time.time()
for _ in range(50):
    u.append(burgers.forward(dt=0.5, # seconds
                               #source_term=4*[0.]+3*[0.]+4*[0.]
                               )
            )
print(time.time()-start)
plt.plot(np.transpose(u));
u_exp = u
# Out:
# Time step 1 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 0.5s
# Time step 2 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 1.0s
# Time step 3 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 1.5s
# Time step 4 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 2.0s
# Time step 5 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 2.5s
# Time step 6 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 3.0s
# Time step 7 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 3.5s
# Time step 8 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 4.0s
# Time step 9 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 4.5s
# Time step 10 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 5.0s
# Time step 11 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 5.5s
# Time step 12 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 6.0s
# Time step 13 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 6.5s
# Time step 14 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 7.0s
# Time step 15 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 7.5s
# Time step 16 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 8.0s
# Time step 17 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 8.5s
# Time step 18 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 9.0s
# Time step 19 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 9.5s
# Time step 20 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 10.0s
# Time step 21 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 10.5s
# Time step 22 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 11.0s
# Time step 23 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 11.5s
# Time step 24 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 12.0s
# Time step 25 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 12.5s
# Time step 26 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 13.0s
# Time step 27 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 13.5s
# Time step 28 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 14.0s
# Time step 29 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 14.5s
# Time step 30 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 15.0s
# Time step 31 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 15.5s
# Time step 32 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 16.0s
# Time step 33 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 16.5s
# Time step 34 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 17.0s
# Time step 35 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 17.5s
# Time step 36 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 18.0s
# Time step 37 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 18.5s
# Time step 38 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 19.0s
# Time step 39 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 19.5s
# Time step 40 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 20.0s
# Time step 41 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 20.5s
# Time step 42 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 21.0s
# Time step 43 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 21.5s
# Time step 44 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 22.0s
# Time step 45 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 22.5s
# Time step 46 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 23.0s
# Time step 47 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 23.5s
# Time step 48 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 24.0s
# Time step 49 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 24.5s
# Time step 50 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 25.0s
# 0.06657123565673828

# %%
#print(u_exp[-1])
#print(u_imp[-1])
fig, axes = plt.subplots(1,2, figsize=(20,5))
axes[0].plot(np.array(u_exp)[:,5])
axes[0].plot(np.array(u_imp)[:,5],'--')
axes[0].legend(['explicit','implicit'])
axes[1].plot(u_exp[-1])
axes[1].plot(u_imp[-1],'--')
axes[1].legend(['explicit','implicit'])

# %% [markdown]
# ### Solve Crank-Nicolson

# %%
burgers = Burgers(alpha=0.0,
            dx=1.0,
            N=150, 
            initial_condition = list(np.sin(np.linspace(0,2*np.pi,150,endpoint=False))+0.5), #50*[10.]+50*[0.]+50*[0.], 
            #boundary_type = ['Dirichlet','Neumann'], 
            #boundary_type = ['Dirichlet','Dirichlet'], 
            boundary_type = ['Neumann','Neumann'], 
            #boundary_type = ['periodic','periodic'], 
            boundary_values = [0, 0],
            time_integration='Crank-Nicolson',
            space_discretization='upwind')

# %%
# Initialize u
u=[]
u.append(burgers.u_previous.copy())  # Initial condition

# %%
start = time.time()
for _ in range(50):
    u.append(burgers.forward(dt=0.5, # seconds
                               #source_term=1*[0.]+9*[0.]+1*[0.]
                               )
            )
print(time.time()-start)
plt.plot(np.transpose(u));
u_cn = u
# Out:
# Time step 1 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 0.5s
# Nonlinear iteration 0 error: 0.02115862641969714
# Nonlinear iteration 1 error: 0.00044309076507021247
# Time step 2 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 1.0s
# Nonlinear iteration 0 error: 0.021617805273274327
# Nonlinear iteration 1 error: 0.00046236053803364095
# Time step 3 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 1.5s
# Nonlinear iteration 0 error: 0.02209394863924752
# Nonlinear iteration 1 error: 0.0004827569481853153
# Time step 4 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 2.0s
# Nonlinear iteration 0 error: 0.022587474602762482
# Nonlinear iteration 1 error: 0.0005045871589110687
# Time step 5 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 2.5s
# Nonlinear iteration 0 error: 0.023112123370088573
# Nonlinear iteration 1 error: 0.0005281513754500442
# Time step 6 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 3.0s
# Nonlinear iteration 0 error: 0.02365922256683812
# Nonlinear iteration 1 error: 0.0005531933451203301
# Time step 7 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 3.5s
# Nonlinear iteration 0 error: 0.024227713954902516
# Nonlinear iteration 1 error: 0.0005797969901102992
# Time step 8 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 4.0s
# Nonlinear iteration 0 error: 0.024823453171777893
# Nonlinear iteration 1 error: 0.0006088298381924047
# Time step 9 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 4.5s
# Nonlinear iteration 0 error: 0.025458696906858903
# Nonlinear iteration 1 error: 0.0006400416910443701
# Time step 10 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 5.0s
# Nonlinear iteration 0 error: 0.026120736785234872
# Nonlinear iteration 1 error: 0.000673353147820225
# Time step 11 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 5.5s
# Nonlinear iteration 0 error: 0.02681006251053903
# Nonlinear iteration 1 error: 0.000709117261958959
# Time step 12 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 6.0s
# Nonlinear iteration 0 error: 0.02754699436440758
# Nonlinear iteration 1 error: 0.0007486977725178381
# Time step 13 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 6.5s
# Nonlinear iteration 0 error: 0.028327821267140885
# Nonlinear iteration 1 error: 0.0007911740760108738
# Time step 14 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 7.0s
# Nonlinear iteration 0 error: 0.029143578475884127
# Nonlinear iteration 1 error: 0.0008367122812865615
# Time step 15 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 7.5s
# Nonlinear iteration 0 error: 0.029995809524751352
# Nonlinear iteration 1 error: 0.0008868729490226931
# Time step 16 => dt = 0.5s, cfl = 0.75, r = 0.00, total time = 8.0s
# Nonlinear iteration 0 error: 0.030930516897759892
# Nonlinear iteration 1 error: 0.0009421960732398413
# Time step 17 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 8.5s
# Nonlinear iteration 0 error: 0.03191113337838441
# Nonlinear iteration 1 error: 0.0010018926561596957
# Nonlinear iteration 2 error: 3.241438269494523e-05
# Time step 18 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 9.0s
# Nonlinear iteration 0 error: 0.03293875886348179
# Nonlinear iteration 1 error: 0.001066233164721421
# Nonlinear iteration 2 error: 3.56400931764877e-05
# Time step 19 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 9.5s
# Nonlinear iteration 0 error: 0.03404100999796344
# Nonlinear iteration 1 error: 0.0011398196434320778
# Nonlinear iteration 2 error: 3.942117836967111e-05
# Time step 20 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 10.0s
# Nonlinear iteration 0 error: 0.03524335342383074
# Nonlinear iteration 1 error: 0.0012202739078965598
# Nonlinear iteration 2 error: 4.367167282754963e-05
# Time step 21 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 10.5s
# Nonlinear iteration 0 error: 0.03650839268211714
# Nonlinear iteration 1 error: 0.0013075753508310307
# Nonlinear iteration 2 error: 4.843758338791359e-05
# Time step 22 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 11.0s
# Nonlinear iteration 0 error: 0.03783455394640347
# Nonlinear iteration 1 error: 0.001404257031364434
# Nonlinear iteration 2 error: 5.406450555326697e-05
# Time step 23 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 11.5s
# Nonlinear iteration 0 error: 0.03931613454393055
# Nonlinear iteration 1 error: 0.0015161047027043837
# Nonlinear iteration 2 error: 6.065684145545949e-05
# Time step 24 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 12.0s
# Nonlinear iteration 0 error: 0.04091164754054704
# Nonlinear iteration 1 error: 0.0016386879119401222
# Nonlinear iteration 2 error: 6.815162792021145e-05
# Time step 25 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 12.5s
# Nonlinear iteration 0 error: 0.042593728319272994
# Nonlinear iteration 1 error: 0.0017723520957937525
# Nonlinear iteration 2 error: 7.662593285814576e-05
# Time step 26 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 13.0s
# Nonlinear iteration 0 error: 0.04437872449860188
# Nonlinear iteration 1 error: 0.0019282061185442833
# Nonlinear iteration 2 error: 8.733271047570223e-05
# Time step 27 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 13.5s
# Nonlinear iteration 0 error: 0.0464521791630286
# Nonlinear iteration 1 error: 0.0021077124882879473
# Nonlinear iteration 2 error: 9.979061780933325e-05
# Time step 28 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 14.0s
# Nonlinear iteration 0 error: 0.048656245567788754
# Nonlinear iteration 1 error: 0.0023059106206430955
# Nonlinear iteration 2 error: 0.00011412499661943405
# Time step 29 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 14.5s
# Nonlinear iteration 0 error: 0.050979787418874774
# Nonlinear iteration 1 error: 0.0025226049829817896
# Nonlinear iteration 2 error: 0.00013110499040215704
# Time step 30 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 15.0s
# Nonlinear iteration 0 error: 0.05356896984812854
# Nonlinear iteration 1 error: 0.00279601832051332
# Nonlinear iteration 2 error: 0.0001532656498472524
# Time step 31 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 15.5s
# Nonlinear iteration 0 error: 0.056579398882508306
# Nonlinear iteration 1 error: 0.003107383577166136
# Nonlinear iteration 2 error: 0.00017943010921629826
# Time step 32 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 16.0s
# Nonlinear iteration 0 error: 0.05978838286611315
# Nonlinear iteration 1 error: 0.0034534976497439633
# Nonlinear iteration 2 error: 0.00020990620048713305
# Time step 33 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 16.5s
# Nonlinear iteration 0 error: 0.063157156200888
# Nonlinear iteration 1 error: 0.0038408650310765018
# Nonlinear iteration 2 error: 0.0002486486622544281
# Time step 34 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 17.0s
# Nonlinear iteration 0 error: 0.06718954314274991
# Nonlinear iteration 1 error: 0.004366592727767603
# Nonlinear iteration 2 error: 0.0003011623370427158
# Time step 35 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 17.5s
# Nonlinear iteration 0 error: 0.0719011606826059
# Nonlinear iteration 1 error: 0.004968099036285498
# Nonlinear iteration 2 error: 0.00036477893967664597
# Time step 36 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 18.0s
# Nonlinear iteration 0 error: 0.0769341142966812
# Nonlinear iteration 1 error: 0.005641074576986263
# Nonlinear iteration 2 error: 0.00043989677653186724
# Time step 37 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 18.5s
# Nonlinear iteration 0 error: 0.08216176229286867
# Nonlinear iteration 1 error: 0.006406610717876522
# Nonlinear iteration 2 error: 0.0005418614225000559
# Time step 38 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 19.0s
# Nonlinear iteration 0 error: 0.08894687840901666
# Nonlinear iteration 1 error: 0.007567358512884845
# Nonlinear iteration 2 error: 0.0006942615663619089
# Time step 39 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 19.5s
# Nonlinear iteration 0 error: 0.09723490365634463
# Nonlinear iteration 1 error: 0.008937565728060842
# Nonlinear iteration 2 error: 0.0008876450939024849
# Time step 40 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 20.0s
# Nonlinear iteration 0 error: 0.10616323326033986
# Nonlinear iteration 1 error: 0.010494760901534408
# Nonlinear iteration 2 error: 0.0011225552223557665
# Nonlinear iteration 3 error: 0.00011964211362513718
# Time step 41 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 20.5s
# Nonlinear iteration 0 error: 0.1153235736958051
# Nonlinear iteration 1 error: 0.012157088808161912
# Nonlinear iteration 2 error: 0.0014031255043519392
# Nonlinear iteration 3 error: 0.00016655098068094412
# Time step 42 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 21.0s
# Nonlinear iteration 0 error: 0.12662731927486653
# Nonlinear iteration 1 error: 0.015116159753346846
# Nonlinear iteration 2 error: 0.0020011662306298047
# Nonlinear iteration 3 error: 0.0002663324209762897
# Time step 43 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 21.5s
# Nonlinear iteration 0 error: 0.14449351373047492
# Nonlinear iteration 1 error: 0.01925670541454303
# Nonlinear iteration 2 error: 0.0028609098551824895
# Nonlinear iteration 3 error: 0.000426752896345409
# Time step 44 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 22.0s
# Nonlinear iteration 0 error: 0.16486408947605755
# Nonlinear iteration 1 error: 0.024366766751756586
# Nonlinear iteration 2 error: 0.004037201486060518
# Nonlinear iteration 3 error: 0.0006719216761157274
# Time step 45 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 22.5s
# Nonlinear iteration 0 error: 0.1866792319445036
# Nonlinear iteration 1 error: 0.03019070284763759
# Nonlinear iteration 2 error: 0.005506376245039884
# Nonlinear iteration 3 error: 0.0010113850713394349
# Nonlinear iteration 4 error: 0.00018449908888820528
# Time step 46 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 23.0s
# Nonlinear iteration 0 error: 0.20765785910114137
# Nonlinear iteration 1 error: 0.03596624326015979
# Nonlinear iteration 2 error: 0.0070654826571245975
# Nonlinear iteration 3 error: 0.0014033288730967949
# Nonlinear iteration 4 error: 0.00027761570940797154
# Time step 47 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 23.5s
# Nonlinear iteration 0 error: 0.2241613802390089
# Nonlinear iteration 1 error: 0.040332351597265385
# Nonlinear iteration 2 error: 0.00826262386177252
# Nonlinear iteration 3 error: 0.0017179532624258013
# Nonlinear iteration 4 error: 0.0003567793935996641
# Time step 48 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 24.0s
# Nonlinear iteration 0 error: 0.23170933176798264
# Nonlinear iteration 1 error: 0.041618211554283996
# Nonlinear iteration 2 error: 0.008510289659289707
# Nonlinear iteration 3 error: 0.0017697054379384118
# Nonlinear iteration 4 error: 0.00036824482131318147
# Time step 49 => dt = 0.5s, cfl = 0.74, r = 0.00, total time = 24.5s
# Nonlinear iteration 0 error: 0.22648649412142818
# Nonlinear iteration 1 error: 0.03868458165447158
# Nonlinear iteration 2 error: 0.007478631051585584
# Nonlinear iteration 3 error: 0.0014690558677397626
# Nonlinear iteration 4 error: 0.000288878878076015
# Time step 50 => dt = 0.5s, cfl = 0.73, r = 0.00, total time = 25.0s
# Nonlinear iteration 0 error: 0.20748086510190644
# Nonlinear iteration 1 error: 0.031906486798453614
# Nonlinear iteration 2 error: 0.0054864416203541525
# Nonlinear iteration 3 error: 0.0009551881401996465
# 1.2956242561340332

# %%
#print('A = \n', transport.A)
print()
#print('u = \n', u[-1])
print()
#print('f = \n', transport.f)
print()
print('Determinant =', np.linalg.det(burgers.A))
print('Error = ', np.max(abs(burgers.A.dot(u[-1])-burgers.f)))

plt.plot(burgers.A.dot(u[-1]))
plt.plot(burgers.f, '--')
# Out:
# Determinant = 23955875364.01186
# Error =  2.0512480602974392e-12

# %%
#print(u_exp[-1])
#print(u_imp[-1])
#print(u_cn[-1])
fig, axes = plt.subplots(1,2, figsize=(20,5))
axes[0].plot(np.array(u_exp)[:,5])
axes[0].plot(np.array(u_imp)[:,5],'--')
axes[0].plot(np.array(u_cn)[:,5],'-.')
axes[0].legend(['explicit','implicit','Crank-Nicolson'])
axes[1].plot(u_exp[-1])
axes[1].plot(u_imp[-1],'--')
axes[1].plot(u_cn[-1],'-.')
axes[1].legend(['explicit','implicit','Crank-Nicolson'])
